# %%
from pyScatt.libs import *
from pyScatt.packages import *
# Out:
# WARNING:silx.opencl.common:Unable to import pyOpenCl. Please install it from: https://pypi.org/project/pyopencl
# The GA is not availabel.

# %% [markdown]
# # CHX Calculate

# %% [markdown]
# ## E-beam
# * Electron beam size (RMS):
# * σₑ,ₓ = 36 μm (horizontal)
# * σₑ,ᵧ = 2.6 μm (vertical)
# * Electron beam divergence (RMS):
# * σₑ,ₓ' = 16.6 μrad (horizontal)
# * σₑ,ᵧ' = 2.8 μrad (vertical)
# * Emittance: εₓ = 0.55 nm·rad (horizontal)
# * εᵧ = 0.008 nm·rad (vertical)

# %%
36 * 1e3 * 16.6 *1e-6, 2.6 * 1e3 * 2.8 *1e-6,
# Out:
# (0.5976, 0.007279999999999999)

# %% [markdown]
# ### Photon source phase space:
# * Horizontal: Γₓ = σₓ × σₓ' = 36.3 μm × 18.6 μrad = 0.675 μm·mrad
# * Vertical: Γᵧ = 5.0 μm × 8.9 μrad = 0.0445 μm·mrad

# %%
np.sqrt( 36.3 **2 + ( 18.6 * 20.5 )**2  )
# Out:
# 383.02399402648393

# %%
np.sqrt( 34.1 **2 + ( 18.6 * 34.3 )**2  )
# Out:
# 638.8906717115221

# %%
np.sqrt( 7.5**2 + ( 7.7 * 34.3 )**2  )
# Out:
# 264.21646826040194

# %%
34.3 *1e6 * 1e-4 / ( 4*np.pi * 34.1 )
# Out:
# 8.004420158434032

# %%
34.3 *1e6 * 1e-4 / ( 4*np.pi * 7.5 )
# Out:
# 36.39343032034674

# %%
1.24/(4*np.pi)*0.1
# Out:
# 0.009867606471697512

# %%
34*18*1e-3 / ( 1.24/(4*np.pi)*0.1 )
# Out:
# 62.02111948377269

# %%
1.24 *1e-4 * 34.3 * 1e6 / (4* np.pi * 34 )
# Out:
# 9.954673587624253

# %%
1.24 *1e-4 * 34.3 * 1e6 / (4* np.pi * 8 )
# Out:
# 42.307362747403076

# %%
np.sqrt( 34**2 + (18.0 * 34.1 )**2)
# Out:
# 614.7409535731291

# %%
np.sqrt( 34**2 + ( 7.5*7.7 )**2)
# Out:
# 67.01539002348639

# %%
100 *150 / ( 638 * 72 ) * 360
# Out:
# 117.55485893416929

# %%
100   / ( 638   ) * 60 * 6
# Out:
# 56.426332288401255
